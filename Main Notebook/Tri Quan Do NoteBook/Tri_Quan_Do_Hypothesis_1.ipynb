# %%
# !pip install pandas
# !pip install numpy
# !pip install -U scikit-learn
# !pip install seaborn

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns; sns.set()
import numpy as np
import pandas as pd

from sklearn.linear_model import LinearRegression # Modeling for Machine Learning Task
from sklearn.datasets import load_diabetes
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.feature_selection import RFE
from sklearn.model_selection import KFold
from sklearn.model_selection import cross_val_score
from sklearn.feature_selection import RFECV

# %%
# Some critical list declarations
file_01_05 = "Chicago_Crimes_2001_to_2005.csv"
file_06_10 = "Chicago_Crimes_2006_to_2010.csv"
file_11_15 = "Chicago_Crimes_2011_to_2015.csv"
file_16_17 = "Chicago_Crimes_2016.csv"
file_17_18 = "Chicago_Crimes_2017.csv"
file_18_19 = "Chicago_Crimes_2018_to_2019.csv"
file_20_22 = "Chicago_Crimes_2020_to_2022.csv"

# Important columns for training
critical_cols = ['Date','Primary Type','Location Description','Arrest','District','Year']
file_path_lst = [file_01_05, file_06_10, file_11_15, file_16_17, 
                 file_17_18, file_18_19, file_20_22]

# %%
def import_data(file_path=file_20_22, expect_col=[], file_list=[], read_many=False):
  # When reading multiples file, return a list of frames
  if read_many is True:
    dataFrame_list = []

    for f_name in file_list:
      data_csv = pd.read_csv(f_name)
      dataFrame_list.append(data_csv)

    dataFrames_Final = []
    # Drop unnecessary columns that only retrieve from expected one
    if len(expect_col) > 0:
      for frame in dataFrame_list:
        new_frame = frame.loc[:, expect_col]
        dataFrames_Final.append(new_frame)
    else:
      dataFrames_Final = dataFrame_list

    return dataFrames_Final

  # Case when import 1 single file only
  data_csv = pd.read_csv(file_path)
  data_csv.dropna(inplace=True)           # drop rows missed value
  data_csv.to_csv(file_path, index=False) # Write back

  # Drop unnecessary columns that only retrieve from expected one
  if len(expect_col) > 0:
    data_csv = data_csv.loc[:, expect_col]

  return data_csv

# %%
def group_by_col(dataFrame, col_group_name="", col_list=False):
  try:
    if not col_list:
      return dataFrame[col_group_name].value_counts()

    # Performing data count group by for visualization
    my_data = list()
    for column in col_list:
      data_count = dataFrame[column].value_counts()
      my_data.append(data_count)
    return my_data

  except Exception as e:
    print("Internal errors when performing group_by, please check again", str(e))
    return None

# %%
# DataFrame Reading from 2001-2022
chicago_GDP_Frames = import_data(file_list=file_path_lst, expect_col=critical_cols, read_many=True)

# %%
# First 10 rows chicago crime in 2001-2005
chicago_GDP_Frames[0].head(10)
# Out:
#               Date         Primary Type Location Description  Arrest  \
# 0   1/1/2001 11:00   DECEPTIVE PRACTICE            RESIDENCE   False
# 1    1/1/2003 0:01          SEX OFFENSE            RESIDENCE   False
# 2   9/15/2001 2:00              BATTERY               STREET   False
# 3  11/2/2001 18:30                THEFT                OTHER   False
# 4  12/15/2001 2:00              BATTERY               STREET   False
# 5  9/26/2002 13:30              BATTERY               STREET   False
# 6  10/1/2002 19:00  MOTOR VEHICLE THEFT               STREET   False
# 7  11/5/2002 16:40              ROBBERY               STREET    True
# 8    8/7/2005 7:15                THEFT               STREET   False
# 9   10/1/2005 9:00                THEFT                OTHER    True
#
#    District  Year
# 0         4  2001
# 1         8  2003
# 2        12  2001
# 3         1  2001
# 4        18  2001
# 5         8  2002
# 6        14  2002
# 7         8  2002
# 8        25  2005
# 9        10  2005

# %%
# First 10 rows chicago crime in 2006-2010
chicago_GDP_Frames[1].head(10)
# Out:
#                Date                Primary Type Location Description  Arrest  \
# 0     1/1/2007 0:01         CRIM SEXUAL ASSAULT            RESIDENCE   False
# 1     1/1/2010 0:01         CRIM SEXUAL ASSAULT            RESIDENCE   False
# 2     1/1/2007 0:01         CRIM SEXUAL ASSAULT            RESIDENCE   False
# 3     1/1/2008 0:01         CRIM SEXUAL ASSAULT            RESIDENCE   False
# 4     1/1/2007 0:01         CRIM SEXUAL ASSAULT      DAY CARE CENTER   False
# 5  10/24/2008 14:30          DECEPTIVE PRACTICE            APARTMENT   False
# 6   1/24/2009 18:00  OFFENSE INVOLVING CHILDREN            RESIDENCE    True
# 7    7/24/2008 0:01                 SEX OFFENSE            APARTMENT   False
# 8    8/4/2009 12:00          DECEPTIVE PRACTICE            RESIDENCE   False
# 9     1/1/2009 0:00         CRIM SEXUAL ASSAULT            RESIDENCE    True
#
#    District  Year
# 0        11  2007
# 1         6  2010
# 2        10  2007
# 3        11  2008
# 4        25  2007
# 5        16  2008
# 6         9  2009
# 7        11  2008
# 8         3  2009
# 9         6  2009

# %%
# First 10 rows chicago crime in 2011-2015
chicago_GDP_Frames[2].head(10)
# Out:
#              Date Primary Type            Location Description  Arrest  \
# 0  9/5/2015 13:30      BATTERY                       RESIDENCE   False
# 1  9/4/2015 11:30        THEFT                         CTA BUS   False
# 2  9/5/2015 12:45    NARCOTICS                        SIDEWALK    True
# 3  9/5/2015 13:00      ASSAULT                       APARTMENT   False
# 4  9/5/2015 10:55     BURGLARY                       RESIDENCE   False
# 5  9/4/2015 18:00     BURGLARY                RESIDENCE-GARAGE   False
# 6  9/5/2015 13:00        THEFT              GROCERY FOOD STORE    True
# 7  9/5/2015 11:30      ROBBERY                          STREET   False
# 8  9/5/2015 14:00        THEFT  PARKING LOT/GARAGE(NON.RESID.)   False
# 9  9/5/2015 11:00      BATTERY              SMALL RETAIL STORE   False
#
#    District  Year
# 0         9  2015
# 1        15  2015
# 2        14  2015
# 3        15  2015
# 4         6  2015
# 5        14  2015
# 6        10  2015
# 7        12  2015
# 8         8  2015
# 9        16  2015

# %%
# First 10 rows chicago crime in 2016-2017
chicago_GDP_Frames[3].head(10)
# Out:
#                Date         Primary Type         Location Description  Arrest  \
# 0     5/1/2016 0:25   DECEPTIVE PRACTICE                          NaN   False
# 1  10/19/2016 19:00             BURGLARY                   RESTAURANT   False
# 2    3/29/2016 7:00   DECEPTIVE PRACTICE                        OTHER   False
# 3   3/11/2016 23:00  CRIM SEXUAL ASSAULT      RESIDENCE PORCH/HALLWAY   False
# 4    1/1/2016 11:00   DECEPTIVE PRACTICE                    RESIDENCE   False
# 5     3/1/2016 0:00        OTHER OFFENSE  AUTO / BOAT / RV DEALERSHIP   False
# 6    12/1/2016 0:01   DECEPTIVE PRACTICE                    RESIDENCE   False
# 7     4/1/2016 0:00   DECEPTIVE PRACTICE                    RESIDENCE   False
# 8    9/13/2016 9:55   DECEPTIVE PRACTICE                          NaN   False
# 9     5/8/2016 9:45   DECEPTIVE PRACTICE                          NaN   False
#
#    District  Year
# 0         8  2016
# 1         4  2016
# 2         3  2016
# 3        17  2016
# 4         5  2016
# 5        22  2016
# 6         3  2016
# 7        18  2016
# 8        15  2016
# 9         7  2016

# %%
# First 10 rows chicago crime in 2017-2018
chicago_GDP_Frames[4].head(10)
# Out:
#                Date                Primary Type Location Description  Arrest  \
# 0    10/8/2017 3:00         CRIM SEXUAL ASSAULT            RESIDENCE   False
# 1   3/28/2017 14:00                    BURGLARY                OTHER   False
# 2    9/9/2017 20:17                       THEFT            RESIDENCE   False
# 3   8/26/2017 10:00         CRIM SEXUAL ASSAULT          HOTEL/MOTEL   False
# 4     1/1/2017 0:01  OFFENSE INVOLVING CHILDREN            RESIDENCE   False
# 5   7/17/2017 10:10                       THEFT            RESIDENCE   False
# 6  12/28/2017 15:55          DECEPTIVE PRACTICE                  NaN   False
# 7   2/10/2017 12:00             CRIMINAL DAMAGE            APARTMENT   False
# 8   11/22/2017 2:42               OTHER OFFENSE            APARTMENT   False
# 9   7/29/2017 15:40                       THEFT             SIDEWALK   False
#
#    District  Year
# 0      22.0  2017
# 1       8.0  2017
# 2       3.0  2017
# 3       1.0  2017
# 4      10.0  2017
# 5      14.0  2017
# 6       1.0  2017
# 7       6.0  2017
# 8      17.0  2017
# 9      24.0  2017

# %%
# First 10 rows chicago crime in 2018-2019
chicago_GDP_Frames[5].head(10)
# Out:
#                Date        Primary Type          Location Description  Arrest  \
# 0     9/1/2018 0:01               THEFT                     RESIDENCE   False
# 1     1/1/2018 8:00  DECEPTIVE PRACTICE                     RESIDENCE   False
# 2    9/24/2019 8:00  DECEPTIVE PRACTICE  COMMERCIAL / BUSINESS OFFICE   False
# 3  10/13/2019 20:30               THEFT            GROCERY FOOD STORE   False
# 4  12/20/2018 16:00       OTHER OFFENSE                     RESIDENCE   False
# 5     4/1/2018 0:01  DECEPTIVE PRACTICE                     RESIDENCE   False
# 6  12/20/2018 15:00  DECEPTIVE PRACTICE                     APARTMENT   False
# 7   10/5/2019 18:30               THEFT                     RESIDENCE   False
# 8  12/18/2018 11:00  DECEPTIVE PRACTICE                     RESIDENCE   False
# 9  10/13/2019 19:00     CRIMINAL DAMAGE                        STREET   False
#
#    District  Year
# 0         6  2018
# 1        25  2018
# 2         1  2019
# 3        12  2019
# 4        17  2018
# 5         6  2018
# 6        25  2018
# 7        12  2019
# 8        19  2018
# 9        19  2019

# %%
# First 10 rows chicago crime in 2020-2022
chicago_GDP_Frames[6].head(10)
# Out:
#               Date         Primary Type Location Description  Arrest  \
# 0  3/17/2020 21:30                THEFT               STREET   False
# 1   3/18/2020 2:03  MOTOR VEHICLE THEFT            APARTMENT   False
# 2   3/18/2020 8:50              ASSAULT            RESIDENCE   False
# 3  3/18/2020 13:00   DECEPTIVE PRACTICE      OTHER (SPECIFY)   False
# 4  3/18/2020 17:35            NARCOTICS             SIDEWALK    True
# 5   3/16/2020 0:05                THEFT               STREET   False
# 6  3/18/2020 18:00              ROBBERY               STREET   False
# 7  3/18/2020 14:04              BATTERY            RESIDENCE   False
# 8  3/18/2020 21:27        OTHER OFFENSE             SIDEWALK   False
# 9   3/18/2020 7:30                THEFT               STREET   False
#
#    District  Year
# 0        16  2020
# 1        11  2020
# 2        25  2020
# 3        11  2020
# 4        15  2020
# 5         2  2020
# 6        10  2020
# 7         4  2020
# 8         9  2020
# 9        25  2020
